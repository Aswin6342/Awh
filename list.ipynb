# %%
mark=[120,119,115,12];
print(mark[0]);
# Out:
# 120

# %%
mark=[120,119,115,12];
mark.append(112);
print(mark);
# Out:
# [120, 119, 115, 12, 112]

# %%
num=(1,2,3,4,5)
print(num[2])
# Out:
# 3

# %%
a={1,2,1,"ldjw"}
print(a)
# Out:
# {1, 2, 'ldjw'}

# %%
d={"name":"Aswin","age":22,"mark":120}
print(d["name"]);
# Out:
# Aswin

# %%
s="infrom";
print(f"{s[0]} , {s[-1]}")
