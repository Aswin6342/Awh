# %%
n=int(input("enter a num"))
print(f"previous:{n-1} \n next: {n+1}")
# Out:
# enter a num5
# previous:4
#  next: 6

# %%
b=int(input("enter base"))
h=int(input("enter height"))
a=0.5*b*h
print(a)
# Out:
# enter base2
# enter height3
# 3.0

# %%
p=int(input("enter principle amont"))
y=int(input("enter no. of years"))
r=int(input("enter rate"))
s=p*r*y
print(s)
# Out:
# enter principle amont2000
# enter no. of years2
# enter rate10
# 40000
