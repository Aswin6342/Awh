# %%
n=int(input("enter a number"))
if(n>50):
    print("great");
# Out:
# enter a number5
# not

# %%
n=int(input("enter a number"))
if(n>50):
    print("great");
else:
    print("not great")
# Out:
# enter a number56
# great

# %%
n=int(input("enter a number"))
if(n>50):
    print("great");
elif(n<100):
    print("great than 100")
    
else:
    print("not")
# Out:
# enter a number56
# great

# %%
n=int(input("enter a number"))
if(n>0):
    print("positive")
else:
    print("negative")
# Out:
# enter a number-1
# negative

# %%
n=int(input("enter a number"))
if(n%2==0):
    print("even");
else:
    print("odd")
# Out:
# enter a number11
# odd

# %%
n=int(input("enter a number"))
m=int(input("enter a number"))
if(n>m):
    print(f"{n} is great");
else:
    print(f"{m} is great")
# Out:
# enter a number5
# enter a number7
# 7 is great

# %%
n=int(input("enter a number"))
if(n>100):
    print("great");
else:
    print("not great")
# Out:
# enter a number123
# great

# %%
n=int(input("enter a age "))
if(n>17):
    print("eligible");
else:
    print("not eligible")
# Out:
# enter a age 12
# not eligible

# %%
n=int(input("enter a number"))
if(n%5==0):
    print("divisible");
else:
    print("not  divisible")
# Out:
# enter a number25
# divisible
