# %%
a=int(input("enter first num"))
b=int(input("enter second number"))
sum=a+b;
dif=a-b;
pro=a*b;
print(sum,dif,pro)
# Out:
# enter first num10
# enter second number5
# 15 5 50

# %%
a=int(input("enter first num"))
b=int(input("enter second number"))
qu=a/b;
r=a%b;
print(qu,r)
# Out:
# enter first num10
# enter second number5
# 2.0 0

# %%
r=int(input("enter radius"))
a=3.14*r*r
print(a)
# Out:
# enter radius3
# 28.259999999999998

# %%
a=int(input("enter first num"))
b=int(input("enter second number"))
c=int(input("enter third num"))
sum=a+b+c;
avg=sum/3;
print(avg)
# Out:
# enter first num1
# enter second number2
# enter third num3
# 2.0

# %%
t=int(input("enter temp in celcius"))
f=(t*(9/5))+32
print(f)
# Out:
# enter temp in celcius20
# 68.0
